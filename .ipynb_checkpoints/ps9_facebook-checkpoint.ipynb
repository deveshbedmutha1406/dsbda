# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DSBDALExam DataSets/dataset_Facebook.csv", sep=';')
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
photo_subset = df[df['Type'] == 'Photo']
photo_subset.shape
# Out:
# (426, 19)

# %%
video_subset = df[df['Type'] =='Video']
video_subset.shape
# Out:
# (7, 19)

# %%
key1 = {
    "col1": ['a', 'b', 'c']
}
df1 = pd.DataFrame(data=key1)

key2 = {
    "col1": ['e', 'f', 'g']
}
df2 = pd.DataFrame(data=key2)

df3 = pd.concat([df1, df2])
df3 = df3.reset_index(drop=True)

# %%
merged_subset = pd.concat([photo_subset, video_subset])
merged_subset.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
merged_subset.shape
# Out:
# (433, 19)

# %%
merged_subset['Type'].unique()
# Out:
# array(['Photo', 'Video'], dtype=object)

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.sort_values(by='like', ascending=False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
df3.head()
# Out:
#   col1
# 0    a
# 1    b
# 2    c
# 3    e
# 4    f

# %%
sub1 = df[['Type', 'Category']]
sub1.head()
# Out:
#      Type  Category
# 0   Photo         2
# 1  Status         2
# 2   Photo         3
# 3   Photo         2
# 4   Photo         2

# %%
newsub = sub1.T
newsub
# Out:
#             0       1      2      3      4       5      6      7       8    \
# Type      Photo  Status  Photo  Photo  Photo  Status  Photo  Photo  Status
# Category      2       2      3      2      2       2      3      3       2
#
#             9    ...    490    491   492    493    494    495    496    497  \
# Type      Photo  ...  Photo  Photo  Link  Photo  Photo  Photo  Photo  Photo
# Category      3  ...      3      3     1      3      3      3      2      1
#
#             498    499
# Type      Photo  Photo
# Category      3      2
#
# [2 rows x 500 columns]

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
sub2 = df[['comment', 'like', 'share', 'Total Interactions']]
sub2.head()
# Out:
#    comment    like  share  Total Interactions
# 0        4    79.0   17.0                 100
# 1        5   130.0   29.0                 164
# 2        0    66.0   14.0                  80
# 3       58  1572.0  147.0                1777
# 4       19   325.0   49.0                 393

# %%
new_sub2 = pd.melt(sub2, id_vars=['comment', 'like'], var_name='metric', value_name='newname1')
new_sub2
# Out:
#      comment    like              metric  newname1
# 0          4    79.0               share      17.0
# 1          5   130.0               share      29.0
# 2          0    66.0               share      14.0
# 3         58  1572.0               share     147.0
# 4         19   325.0               share      49.0
# ..       ...     ...                 ...       ...
# 995        5    53.0  Total Interactions      84.0
# 996        0    53.0  Total Interactions      75.0
# 997        4    93.0  Total Interactions     115.0
# 998        7    91.0  Total Interactions     136.0
# 999        0    91.0  Total Interactions     119.0
#
# [1000 rows x 4 columns]

# %%
sub3 = df[['Page total likes', 'Type', 'Total Interactions']]
sub3.head()
# Out:
#    Page total likes    Type  Total Interactions
# 0            139441   Photo                 100
# 1            139441  Status                 164
# 2            139441   Photo                  80
# 3            139441   Photo                1777
# 4            139441   Photo                 393

# %%
new_sub3 = sub3.pivot_table(index='Page total likes', columns='Type', values='Total Interactions', aggfunc='min')
new_sub3.fillna(0, inplace=True)
new_sub3
# Out:
# Type               Link  Photo  Status  Video
# Page total likes
# 81370               0.0   75.0     0.0    0.0
# 85093               0.0   84.0     0.0    0.0
# 85979             137.0   66.0     0.0    0.0
# 86491               7.0   97.0     0.0    0.0
# 86909             107.0   84.0     0.0    0.0
# ...                 ...    ...     ...    ...
# 138353             14.0   36.0   214.0    0.0
# 138414             18.0    0.0    75.0    0.0
# 138458              0.0  117.0   106.0    0.0
# 138895            211.0   39.0   262.0  174.0
# 139441              0.0   80.0   164.0    0.0
#
# [90 rows x 4 columns]
