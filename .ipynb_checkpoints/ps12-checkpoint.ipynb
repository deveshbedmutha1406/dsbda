# %%
import pandas as pd
df = pd.read_csv('DSBDALExam DataSets/Adult/adult.csv')
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.eq('?').sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
var = df['workclass'].mode()[0]
var
# Out:
# 'Private'

# %%
df.loc[df['workclass'].eq("?"), 'workclass'] = var

# %%
df.eq('?').sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
df['occupation'].value_counts()
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df.loc[df['occupation'].eq('?'), 'occupation'] = df['occupation'].mode()[0]
df.eq("?").sum()
# Out:
# age                 0
# workclass           0
# fnlwgt              0
# education           0
# education.num       0
# marital.status      0
# occupation          0
# relationship        0
# race                0
# sex                 0
# capital.gain        0
# capital.loss        0
# hours.per.week      0
# native.country    583
# income              0
# dtype: int64

# %%
df[df['native.country'].eq('?')]
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 9       41           Private   70037  Some-college             10
# 18      22           Private  119592    Assoc-acdm             12
# 65      60      Self-emp-inc  226355     Assoc-voc             11
# 86      39  Self-emp-not-inc  218490   Prof-school             15
# 87      43       Federal-gov  156996   Prof-school             15
# ...    ...               ...     ...           ...            ...
# 32459   44      Self-emp-inc   71556       Masters             14
# 32476   58      Self-emp-inc  181974     Doctorate             16
# 32498   42  Self-emp-not-inc  217597       HS-grad              9
# 32515   39           Private  107302       HS-grad              9
# 32528   81           Private  120478     Assoc-voc             11
#
#            marital.status         occupation   relationship  \
# 9           Never-married       Craft-repair      Unmarried
# ...

# %%
df.loc[df['native.country'].eq("?"), 'native.country'] = df['native.country'].mode()[0]
df.eq("?").sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
len(df['native.country'].unique())
# Out:
# 41

# %%
df['native.country'].value_counts()
# Out:
# United-States                 29753
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# ...

# %%
us = df[df['native.country'] == 'United-States']
us
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90   Private   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66   Private  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
Mexico = df[df['native.country'] == 'Mexico']
Mexico
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 26      33           Private  228696       1st-4th              2
# 217     41      Self-emp-inc  139916     Assoc-voc             11
# 226     47  Self-emp-not-inc  191175       5th-6th              3
# 881     45         Local-gov  199590  Some-college             10
# 1106    26           Private  322614     Preschool              1
# ...    ...               ...     ...           ...            ...
# 32356   26           Private  233777       HS-grad              9
# 32358   24           Private  176580       5th-6th              3
# 32439   23           Private  180771       1st-4th              2
# 32446   36           Private  208068     Preschool              1
# 32549   43           Private  260761       HS-grad              9
#
#               marital.status         occupation   relationship  \
# 26        Married-civ-spouse       Craft-repair  Not-in-family
# ...

# %%
df['sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
female = df[df['sex'] == 'Female']
male = df[df['sex'] == 'Male']
male
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 6       38           Private  150601          10th              6
# 9       41           Private   70037  Some-college             10
# 11      38  Self-emp-not-inc  164526   Prof-school             15
# 13      32           Private  136204       Masters             14
# 14      51           Private  172175     Doctorate             16
# ...    ...               ...     ...           ...            ...
# 32554   32           Private  116138       Masters             14
# 32555   53           Private  321865       Masters             14
# 32556   22           Private  310152  Some-college             10
# 32558   40           Private  154374       HS-grad              9
# 32560   22           Private  201490       HS-grad              9
#
#            marital.status         occupation   relationship  \
# 6               Separated       Adm-clerical      Unmarried
# ...

# %%
import seaborn as sns
ax = sns.countplot(x='sex', data=df)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}',  (p.get_x() + p.get_width() / 2, p.get_height()))

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90   Private   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66   Private  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0     Prof-specialty  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2     Prof-specialty      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
sub1 = df.loc[:,['native.country', 'income', 'sex', 'race']]
sub1
# Out:
#       native.country income     sex   race
# 0      United-States  <=50K  Female  White
# 1      United-States  <=50K  Female  White
# 2      United-States  <=50K  Female  Black
# 3      United-States  <=50K  Female  White
# 4      United-States  <=50K  Female  White
# ...              ...    ...     ...    ...
# 32556  United-States  <=50K    Male  White
# 32557  United-States  <=50K  Female  White
# 32558  United-States   >50K    Male  White
# 32559  United-States  <=50K  Female  White
# 32560  United-States  <=50K    Male  White
#
# [32561 rows x 4 columns]

# %%
help(pd.melt)
# Out:
# Help on function melt in module pandas.core.reshape.melt:
#
# melt(frame: 'DataFrame', id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index: 'bool' = True) -> 'DataFrame'
#     Unpivot a DataFrame from wide to long format, optionally leaving identifiers set.
#
#     This function is useful to massage a DataFrame into a format where one
#     or more columns are identifier variables (`id_vars`), while all other
#     columns, considered measured variables (`value_vars`), are "unpivoted" to
#     the row axis, leaving just two non-identifier columns, 'variable' and
#     'value'.
#
#     Parameters
#     ----------
#     id_vars : tuple, list, or ndarray, optional
#         Column(s) to use as identifier variables.
#     value_vars : tuple, list, or ndarray, optional
#         Column(s) to unpivot. If not specified, uses all columns that
#         are not set as `id_vars`.
#     var_name : scalar
# ...

# %%
sub1.melt(id_vars=['race', 'sex'], var_name='var1', value_name='val')
# Out:
#         race     sex            var1            val
# 0      White  Female  native.country  United-States
# 1      White  Female  native.country  United-States
# 2      Black  Female  native.country  United-States
# 3      White  Female  native.country  United-States
# 4      White  Female  native.country  United-States
# ...      ...     ...             ...            ...
# 65117  White    Male          income          <=50K
# 65118  White  Female          income          <=50K
# 65119  White    Male          income           >50K
# 65120  White  Female          income          <=50K
# 65121  White    Male          income          <=50K
#
# [65122 rows x 4 columns]

# %%
help(pd.pivot_table)
# Out:
# Help on function pivot_table in module pandas.core.reshape.pivot:
#
# pivot_table(data: 'DataFrame', values=None, index=None, columns=None, aggfunc: 'AggFuncType' = 'mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True) -> 'DataFrame'
#     Create a spreadsheet-style pivot table as a DataFrame.
#
#     The levels in the pivot table will be stored in MultiIndex objects
#     (hierarchical indexes) on the index and columns of the result DataFrame.
#
#     Parameters
#     ----------
#     data : DataFrame
#     values : column to aggregate, optional
#     index : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
#         list can contain any of the other types (except list).
#         Keys to group by on the pivot table index.  If an array is passed,
#         it is being used as the same manner as column values.
# ...

# %%
from sklearn.preprocessing import LabelEncoder
obj = LabelEncoder()
sub1['income'] = obj.fit_transform(sub1['income'])
pd.pivot_table(sub1, index=['native.country', 'race'], sort=False, aggfunc="sum", values='income')
# Out:
#                                        income
# native.country     race
# United-States      White                 6811
#                    Black                  364
# Mexico             White                   32
# Greece             White                    8
# Vietnam            Asian-Pac-Islander       5
# ...                                       ...
# Dominican-Republic Asian-Pac-Islander       0
# Philippines        Black                    0
# Japan              Other                    1
# Hong               Amer-Indian-Eskimo       0
# Ireland            Asian-Pac-Islander       0
#
# [108 rows x 1 columns]

# %%
sub1[(sub1['native.country'] == 'Japan') & (sub1['race'] == 'Other')]
# Out:
#       native.country  income     sex   race
# 31023          Japan       1    Male  Other
# 32133          Japan       0  Female  Other
