# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DSBDALExam DataSets/Admission_Predict.csv')
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
sns.displot(data=df, x=df['Chance of Admit '])

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
new_col = []
for ele in df.columns:
    var = "_".join(ele.split(" "))
    var.lower()
    new_col.append(var)
df.columns = new_col
df.head()
# Out:
#    Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance_of_Admit_     newcol
# 0         1              0.92  addmitted
# 1         1              0.76  addmitted
# 2         1              0.72  addmitted
# 3         1              0.80  addmitted
# 4         0              0.65  addmitted

# %%
mean_val = df.Chance_of_Admit_.std()

# %%
for i in df['Chance_of_Admit_'].values:
    print(i)
    if i <= 0.40:
        df['newcol'] = "not addmited"
    elif i > 0.40 and i < 0.90:
        df['newcol'] = 'addmitted'
    else:
        df['newcol'] = 'partially'
df.head()
# Out:
# 0.92
# 0.76
# 0.72
# 0.8
# 0.65
# 0.9
# 0.75
# 0.68
# 0.5
# 0.45
# 0.52
# 0.84
# 0.78
# 0.62
# 0.61
# 0.54
# 0.66
# 0.65
# 0.63
# 0.62
# 0.64
# 0.7
# 0.94
# 0.95
# 0.97
# 0.94
# 0.76
# 0.44
# 0.46
# 0.54
# 0.65
# 0.74
# 0.91
# 0.9
# 0.94
# 0.88
# 0.64
# 0.58
# 0.52
# 0.48
# 0.46
# 0.49
# 0.53
# 0.87
# 0.91
# 0.88
# 0.86
# 0.89
# 0.82
# 0.78
# 0.76
# 0.56
# 0.78
# 0.72
# 0.7
# 0.64
# 0.64
# 0.46
# 0.36
# 0.42
# 0.48
# 0.47
# 0.54
# 0.56
# 0.52
# 0.55
# 0.61
# 0.57
# 0.68
# 0.78
# 0.94
# 0.96
# 0.93
# 0.84
# 0.74
# 0.72
# 0.74
# 0.64
# 0.44
# 0.46
# 0.5
# 0.96
# 0.92
# 0.92
# 0.94
# 0.76
# 0.72
# 0.66
# 0.64
# 0.74
# 0.64
# 0.38
# 0.34
# 0.44
# 0.36
# 0.42
# 0.48
# 0.86
# 0.9
# 0.79
# 0.71
# 0.64
# 0.62
# 0.57
# 0.74
# 0.69
# 0.87
# 0.91
# 0.93
# 0.68
# 0.61
# 0.69
# 0.62
# 0.72
# 0.59
# 0.66
# 0.56
# 0.45
# 0.47
# 0.71
# 0.94
# 0.94
# 0.57
# 0.61
# 0.57
# 0.64
# 0.85
# 0.78
# 0.84
# 0.92
# 0.96
# 0.77
# 0.71
# 0.79
# 0.89
# 0.82
# 0.76
# 0.71
# 0.8
# 0.78
# 0.84
# 0.9
# 0.92
# 0.97
# ...

# %%
df['newcol'].value_counts()
# Out:
# partially    400
# Name: newcol, dtype: int64

# %%
df[df['Chance_of_Admit_'] <= 0.4]
# Out:
#      Serial_No.  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  \
# 58           59        300           99                  1  3.0   2.0  6.80
# 91           92        299           97                  3  5.0   3.5  7.66
# 92           93        298           98                  2  4.0   3.0  8.03
# 94           95        303           99                  3  2.0   2.5  7.66
# 374         375        315          105                  2  2.0   2.5  7.65
# 375         376        304          101                  2  2.0   2.5  7.66
# 376         377        297           96                  2  2.5   2.0  7.43
#
#      Research  Chance_of_Admit_     newcol
# 58          1              0.36  partially
# 91          0              0.38  partially
# 92          0              0.34  partially
# 94          0              0.36  partially
# 374         0              0.39  partially
# 375         0              0.38  partially
# 376         0              0.34  partially

# %%
# u. Check for duplicate rows and remove it

# v. Plot heat map for the continuous data.

# w. Check for null /Nan values and replace them with appropriate values.

# x. Consider the column with highest correlation in the dataset to build linear regression model to predict chance of admit.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.append(df.iloc[399])

# %%
df.shape
# Out:
# (401, 10)

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.drop(['Serial_No.'], inplace=True, axis=1)

# %%
df.head()
# Out:
#    GRE_Score  TOEFL_Score  University_Rating  SOP  LOR_  CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance_of_Admit_     newcol
# 0              0.92  partially
# 1              0.76  partially
# 2              0.72  partially
# 3              0.80  partially
# 4              0.65  partially

# %%
df.loc[399, 'CGPA'] = None

# %%
df.isnull().sum()
# Out:
# GRE_Score            0
# TOEFL_Score          0
# University_Rating    0
# SOP                  0
# LOR_                 0
# CGPA                 1
# Research             0
# Chance_of_Admit_     0
# newcol               0
# dtype: int64

# %%
df['CGPA'].fillna(df['CGPA'].mean(), inplace=True)
df.loc[399]
# Out:
# GRE_Score                  333
# TOEFL_Score                117
# University_Rating            4
# SOP                        5.0
# LOR_                       4.0
# CGPA                  8.596266
# Research                     1
# Chance_of_Admit_          0.95
# newcol               partially
# Name: 399, dtype: object

# %%
sns.heatmap(df.corr(), cmap='coolwarm', annot=True)
plt.title('Corr HeatMap')
plt.show()

# %%
X = df[['CGPA']].values
X
# Out:
# array([[9.65      ],
#        [8.87      ],
#        [8.        ],
#        [8.67      ],
#        [8.21      ],
#        [9.34      ],
#        [8.2       ],
#        [7.9       ],
#        [8.        ],
#        [8.6       ],
#        [8.4       ],
#        [9.        ],
#        [9.1       ],
#        [8.        ],
#        [8.2       ],
#        [8.3       ],
#        [8.7       ],
#        [8.        ],
#        [8.8       ],
#        [8.5       ],
#        [7.9       ],
#        [8.4       ],
#        [9.5       ],
#        [9.7       ],
#        [9.8       ],
#        [9.6       ],
#        [8.8       ],
#        [7.5       ],
#        [7.2       ],
#        [7.3       ],
#        [8.1       ],
#        [8.3       ],
#        [9.4       ],
#        [9.6       ],
#        [9.8       ],
#        [9.2       ],
#        [8.4       ],
#        [7.8       ],
#        [7.5       ],
#        [7.7       ],
#        [8.        ],
#        [8.2       ],
#        [8.5       ],
# ...

# %%
y = df['Chance_of_Admit_']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
from sklearn import metrics
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 0.005214531055907738

# %%
plt.scatter(x_test, y_test, color='red', marker='x', label='Data')
plt.plot(x_test, y_pred, color='blue', label='line')
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit')
plt.title('Linear Regression')

plt.show()
