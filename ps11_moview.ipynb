# %%
import pandas as pd
df = pd.read_csv('DSBDALExam DataSets/Movie/movies_metadata.csv')
df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3398: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
df.drop(['genres', 'belongs_to_collection','spoken_languages'], inplace=True, axis=1)
df.head()
# Out:
#    adult    budget                              homepage     id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709
# 1  False  65000000                                   NaN   8844  tt0113497
# 2  False         0                                   NaN  15602  tt0113228
# 3  False  16000000                                   NaN  31357  tt0114885
# 4  False         0                                   NaN  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# ...

# %%
df.shape
# Out:
# (45466, 21)

# %%
df.drop(['production_countries', 'poster_path','overview','homepage'], inplace=True, axis=1)
df.head()
# Out:
#    adult    budget     id    imdb_id original_language  \
# 0  False  30000000    862  tt0114709                en
# 1  False  65000000   8844  tt0113497                en
# 2  False         0  15602  tt0113228                en
# 3  False  16000000  31357  tt0114885                en
# 4  False         0  11862  tt0113041                en
#
#                 original_title popularity  \
# 0                    Toy Story  21.946943
# 1                      Jumanji  17.015539
# 2             Grumpier Old Men    11.7129
# 3            Waiting to Exhale   3.859495
# 4  Father of the Bride Part II   8.387519
#
#                                 production_companies release_date  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]   1995-10-30
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...   1995-12-15
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...   1995-12-22
# 3  [{'name': 'Twentieth Century Fox Film Corporat...   1995-12-22
# ...

# %%
df
# Out:
#        adult    budget      id    imdb_id original_language  \
# 0      False  30000000     862  tt0114709                en
# 1      False  65000000    8844  tt0113497                en
# 2      False         0   15602  tt0113228                en
# 3      False  16000000   31357  tt0114885                en
# 4      False         0   11862  tt0113041                en
# ...      ...       ...     ...        ...               ...
# 45461  False         0  439050  tt6209470                fa
# 45462  False         0  111109  tt2028550                tl
# 45463  False         0   67758  tt0303758                en
# 45464  False         0  227506  tt0008536                en
# 45465  False         0  461257  tt6980792                en
#
#                     original_title popularity  \
# 0                        Toy Story  21.946943
# 1                          Jumanji  17.015539
# 2                 Grumpier Old Men    11.7129
# 3                Waiting to Exhale   3.859495
# ...

# %%
df.drop(['production_companies'], inplace=True, axis=1)
df
# Out:
#        adult    budget      id    imdb_id original_language  \
# 0      False  30000000     862  tt0114709                en
# 1      False  65000000    8844  tt0113497                en
# 2      False         0   15602  tt0113228                en
# 3      False  16000000   31357  tt0114885                en
# 4      False         0   11862  tt0113041                en
# ...      ...       ...     ...        ...               ...
# 45461  False         0  439050  tt6209470                fa
# 45462  False         0  111109  tt2028550                tl
# 45463  False         0   67758  tt0303758                en
# 45464  False         0  227506  tt0008536                en
# 45465  False         0  461257  tt6980792                en
#
#                     original_title popularity release_date      revenue  \
# 0                        Toy Story  21.946943   1995-10-30  373554033.0
# 1                          Jumanji  17.015539   1995-12-15  262797249.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              45466 non-null  object
#  1   budget             45466 non-null  object
#  2   id                 45466 non-null  object
#  3   imdb_id            45449 non-null  object
#  4   original_language  45455 non-null  object
#  5   original_title     45466 non-null  object
#  6   popularity         45461 non-null  object
#  7   release_date       45379 non-null  object
#  8   revenue            45460 non-null  float64
#  9   runtime            45203 non-null  float64
#  10  status             45379 non-null  object
#  11  tagline            20412 non-null  object
#  12  title              45460 non-null  object
#  13  video              45460 non-null  object
#  14  vote_average       45460 non-null  float64
#  15  vote_count         45460 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# adult                    0
# budget                   0
# id                       0
# imdb_id                 17
# original_language       11
# original_title           0
# popularity               5
# release_date            87
# revenue                  6
# runtime                263
# status                  87
# tagline              25054
# title                    6
# video                    6
# vote_average             6
# vote_count               6
# dtype: int64

# %%
df.drop(['tagline'], inplace=True, axis=1)
df
# Out:
#        adult    budget      id    imdb_id original_language  \
# 0      False  30000000     862  tt0114709                en
# 1      False  65000000    8844  tt0113497                en
# 2      False         0   15602  tt0113228                en
# 3      False  16000000   31357  tt0114885                en
# 4      False         0   11862  tt0113041                en
# ...      ...       ...     ...        ...               ...
# 45461  False         0  439050  tt6209470                fa
# 45462  False         0  111109  tt2028550                tl
# 45463  False         0   67758  tt0303758                en
# 45464  False         0  227506  tt0008536                en
# 45465  False         0  461257  tt6980792                en
#
#                     original_title popularity release_date      revenue  \
# 0                        Toy Story  21.946943   1995-10-30  373554033.0
# 1                          Jumanji  17.015539   1995-12-15  262797249.0
# ...

# %%
df['original_language'].value_counts()
# Out:
# en       32269
# fr        2438
# it        1529
# ja        1350
# de        1080
#          ...
# zu           1
# qu           1
# 104.0        1
# la           1
# si           1
# Name: original_language, Length: 92, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
sns.countplot(x='original_language', data=df)
# Out:
# <AxesSubplot:xlabel='original_language', ylabel='count'>

# %%
for ele in df['original_language'].unique():
    print(ele)
# Out:
# en
# fr
# zh
# it
# fa
# nl
# de
# cn
# ar
# es
# ru
# sv
# ja
# ko
# sr
# bn
# he
# pt
# wo
# ro
# hu
# cy
# vi
# cs
# da
# no
# nb
# pl
# el
# sh
# xx
# mk
# bo
# ca
# fi
# th
# sk
# bs
# hi
# tr
# is
# ps
# ab
# eo
# ka
# mn
# bm
# zu
# uk
# af
# la
# et
# ku
# fy
# lv
# ta
# sl
# tl
# ur
# rw
# id
# bg
# mr
# lt
# kk
# ms
# sq
# nan
# 104.0
# qu
# te
# am
# jv
# tg
# ml
# hr
# lo
# ay
# kn
# eu
# ne
# pa
# ky
# gl
# 68.0
# uz
# sm
# mt
# 82.0
# hy
# iu
# lb
# si

# %%
df['original_language'] = df['original_language'].astype('object')
df.dtypes
# Out:
# adult                 object
# budget                object
# id                    object
# imdb_id               object
# original_language     object
# original_title        object
# popularity            object
# release_date          object
# revenue              float64
# runtime              float64
# status                object
# title                 object
# video                 object
# vote_average         float64
# vote_count           float64
# dtype: object

# %%
df[df['original_language'] == "104.0"]
# Out:
#                      adult                            budget          id  \
# 19730   - Written by Ørnås  /ff9qCepilowshEtG2GYWwzt2bs4.jpg  1997-08-20
#
#       imdb_id original_language                            original_title  \
# 19730       0             104.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#       popularity release_date  revenue  runtime status title video  \
# 19730        NaN            1      NaN      NaN    NaN   NaN   NaN
#
#        vote_average  vote_count
# 19730           NaN         NaN

# %%
tmp = []
for i, ele in enumerate(df['original_language'].values):
    if ele == "104.0" or ele == "68.0" or ele == "82.0":
        tmp.append(i)

df.loc[tmp]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#                                  budget          id imdb_id original_language  \
# 19730  /ff9qCepilowshEtG2GYWwzt2bs4.jpg  1997-08-20       0             104.0
# 29503  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg  2012-09-29       0              68.0
# 35587  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg  2014-01-01       0              82.0
#
#                                  original_title             popularity  \
# 19730  [{'iso_639_1': 'en', 'name': 'English'}]                    NaN
# 29503      [{'iso_639_1': 'ja', 'name': '日本語'}]                    NaN
# 35587  [{'iso_639_1': 'en', 'name': 'English'}]  Beware Of Frost Bites
#
#       release_date  revenue  runtime status title video  vote_average  \
# ...

# %%
df2 = df.drop(tmp)

# %%
df2['original_language'].unique()
# Out:
# array(['en', 'fr', 'zh', 'it', 'fa', 'nl', 'de', 'cn', 'ar', 'es', 'ru',
#        'sv', 'ja', 'ko', 'sr', 'bn', 'he', 'pt', 'wo', 'ro', 'hu', 'cy',
#        'vi', 'cs', 'da', 'no', 'nb', 'pl', 'el', 'sh', 'xx', 'mk', 'bo',
#        'ca', 'fi', 'th', 'sk', 'bs', 'hi', 'tr', 'is', 'ps', 'ab', 'eo',
#        'ka', 'mn', 'bm', 'zu', 'uk', 'af', 'la', 'et', 'ku', 'fy', 'lv',
#        'ta', 'sl', 'tl', 'ur', 'rw', 'id', 'bg', 'mr', 'lt', 'kk', 'ms',
#        'sq', nan, 'qu', 'te', 'am', 'jv', 'tg', 'ml', 'hr', 'lo', 'ay',
#        'kn', 'eu', 'ne', 'pa', 'ky', 'gl', 'uz', 'sm', 'mt', 'hy', 'iu',
#        'lb', 'si'], dtype=object)

# %%
df.drop(tmp, inplace=True)

# %%
df.isnull().sum()
# Out:
# adult                  0
# budget                 0
# id                     0
# imdb_id               17
# original_language     11
# original_title         0
# popularity             3
# release_date          87
# revenue                3
# runtime              260
# status                84
# title                  3
# video                  3
# vote_average           3
# vote_count             3
# dtype: int64

# %%
mode = df['original_language'].mode()
df['original_language'].fillna('en', inplace=True)
df.isnull().sum()
# Out:
# adult                  0
# budget                 0
# id                     0
# imdb_id               17
# original_language      0
# original_title         0
# popularity             3
# release_date          87
# revenue                3
# runtime              260
# status                84
# title                  3
# video                  3
# vote_average           3
# vote_count             3
# dtype: int64

# %%
import numpy as np
drop_list = df[df['imdb_id'].isnull()].index.tolist()
df.drop(drop_list, inplace=True)
df.isnull().sum()
# Out:
# adult                  0
# budget                 0
# id                     0
# imdb_id                0
# original_language      0
# original_title         0
# popularity             3
# release_date          84
# revenue                3
# runtime              258
# status                84
# title                  3
# video                  3
# vote_average           3
# vote_count             3
# dtype: int64

# %%
df.columns
# Out:
# Index(['adult', 'budget', 'id', 'imdb_id', 'original_language',
#        'original_title', 'popularity', 'release_date', 'revenue', 'runtime',
#        'status', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
sub1 = df.iloc[:, [4,13, 14]]
sub1
# Out:
#       original_language  vote_average  vote_count
# 0                    en           7.7      5415.0
# 1                    en           6.9      2413.0
# 2                    en           6.5        92.0
# 3                    en           6.1        34.0
# 4                    en           5.7       173.0
# ...                 ...           ...         ...
# 45461                fa           4.0         1.0
# 45462                tl           9.0         3.0
# 45463                en           3.8         6.0
# 45464                en           0.0         0.0
# 45465                en           0.0         0.0
#
# [45446 rows x 3 columns]

# %%
sub1.sort_values(by=['vote_average'])
# Out:
#       original_language  vote_average  vote_count
# 45465                en           0.0         0.0
# 33383                el           0.0         0.0
# 4728                 en           0.0         0.0
# 33370                en           0.0         3.0
# 33359                en           0.0         0.0
# ...                 ...           ...         ...
# 29294                en          10.0         1.0
# 21091                tl          10.0         2.0
# 19729                en           NaN         NaN
# 29502                ja           NaN         NaN
# 35586                en           NaN         NaN
#
# [45446 rows x 3 columns]

# %%
sub1.isnull().sum()
# Out:
# original_language    0
# vote_average         3
# vote_count           3
# dtype: int64

# %%
sub1.dropna(inplace=True)
sub1.isnull().sum()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# original_language    0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
sub1.T
# Out:
#                     0       1     2     3      4       5      6     7      \
# original_language      en      en    en    en     en      en     en    en
# vote_average          7.7     6.9   6.5   6.1    5.7     7.7    6.2   5.4
# vote_count         5415.0  2413.0  92.0  34.0  173.0  1886.0  141.0  45.0
#
#                    8       9      ... 45456 45457 45458 45459 45460 45461  \
# original_language     en      en  ...    en    en    en    en    en    fa
# vote_average         5.5     6.6  ...   6.3   7.0   7.0   3.5   5.7   4.0
# vote_count         174.0  1194.0  ...   8.0   2.0   1.0   1.0  26.0   1.0
#
#                   45462 45463 45464 45465
# original_language    tl    en    en    en
# vote_average        9.0   3.8   0.0   0.0
# vote_count          3.0   6.0   0.0   0.0
#
# [3 rows x 45443 columns]

# %%
pd.melt(sub1, id_vars=['original_language'] ,value_name='average&count', var_name='rating')
# Out:
#       original_language        rating  average&count
# 0                    en  vote_average            7.7
# 1                    en  vote_average            6.9
# 2                    en  vote_average            6.5
# 3                    en  vote_average            6.1
# 4                    en  vote_average            5.7
# ...                 ...           ...            ...
# 90881                fa    vote_count            1.0
# 90882                tl    vote_count            3.0
# 90883                en    vote_count            6.0
# 90884                en    vote_count            0.0
# 90885                en    vote_count            0.0
#
# [90886 rows x 3 columns]

# %%
help(pd.pivot_table)
# Out:
# Help on function pivot_table in module pandas.core.reshape.pivot:
#
# pivot_table(data: 'DataFrame', values=None, index=None, columns=None, aggfunc: 'AggFuncType' = 'mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False, sort=True) -> 'DataFrame'
#     Create a spreadsheet-style pivot table as a DataFrame.
#
#     The levels in the pivot table will be stored in MultiIndex objects
#     (hierarchical indexes) on the index and columns of the result DataFrame.
#
#     Parameters
#     ----------
#     data : DataFrame
#     values : column to aggregate, optional
#     index : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
#         list can contain any of the other types (except list).
#         Keys to group by on the pivot table index.  If an array is passed,
#         it is being used as the same manner as column values.
# ...

# %%
pd.pivot_table(sub1, index=['original_language'])
# Out:
#                    vote_average  vote_count
# original_language
# ab                     5.000000   13.200000
# af                     6.200000   51.000000
# am                     7.450000    3.500000
# ar                     6.817949   15.384615
# ay                     6.000000    2.000000
# ...                         ...         ...
# vi                     5.880000   10.400000
# wo                     6.520000    4.600000
# xx                     5.854545   26.333333
# zh                     6.366993   29.156479
# zu                     8.300000    6.000000
#
# [89 rows x 2 columns]

# %%
len(sub1.original_language.unique())
# Out:
# 89
